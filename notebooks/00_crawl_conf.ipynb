# %%
import json
import os
import re
import time
from urllib.parse import urljoin, urlparse

from bs4 import BeautifulSoup
from markdownify import MarkdownConverter
import requests

# %%
# config
years = range(1980, 2023)
months = ['04', '10']
host = 'https://www.churchofjesuschrist.org'
base_dir = '../data'
bs_parser = 'html.parser'
encoding = 'utf-8'
seconds_delay = 30

headers = {
    "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9", 
    "Accept-Encoding": "gzip, deflate, br", 
    "Accept-Language": "en-US,en;q=0.9", 
    "Sec-Ch-Ua": "\"Google Chrome\";v=\"105\", \"Not)A;Brand\";v=\"8\", \"Chromium\";v=\"105\"", 
    "Sec-Ch-Ua-Mobile": "?0", 
    "Sec-Ch-Ua-Platform": "\"Linux\"", 
    "Sec-Fetch-Dest": "document", 
    "Sec-Fetch-Mode": "navigate", 
    "Sec-Fetch-Site": "cross-site", 
    "Sec-Fetch-User": "?1", 
    "Upgrade-Insecure-Requests": "1",     
    "User-Agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/105.0.0.0 Safari/537.36",
}

# %%
class HrefConverter(MarkdownConverter):
    """
    Create a custom MarkdownConverter that joins hrefs with a base url
    """
    def __init__(self, *args, **kwargs):
        super(HrefConverter, self).__init__(*args, **kwargs)
        self.base_url = kwargs.get('base_url','')
        
    def convert_a(self, el, text, convert_as_inline):
        if 'href' in el.attrs:
            el['href'] = urljoin(self.base_url, el['href'])
        return super().convert_a(el, text, convert_as_inline)


# Create shorthand method for custom conversion
def md(html, **options):
    return HrefConverter(**options).convert(html)

# %%
def get_page(url, headers, encoding):
    response = requests.get(url, headers=headers)
    if encoding:
        response.encoding = encoding
    return response.status_code, response.text

# %%
def _is_talk_url(url):
    path_components = urlparse(url).path.split('/')
    # must be 5 components and last component must not end in -session
    return len(path_components) == 6 and not path_components[-1].endswith('-session')
    
def get_talk_urls(base_url, html):
    soup = BeautifulSoup(html, bs_parser)
    return [urljoin(base_url, a['href']) for a in soup.find_all('a', href=True) \
            if _is_talk_url(urljoin(base_url, a['href']))]

# %%
def _clean(text):
    return text.replace(' ', ' ')


def get_talk_info(url, html):
    path_components = urlparse(url).path.split('/')
    year, month = path_components[3:5]
    soup = BeautifulSoup(html, bs_parser)
    title = soup.select_one('article header h1')
    author = soup.select_one('article p.author-name')
    author_role = soup.select_one('article p.author-role')
    body = soup.select_one('article div.body-block')
    content = _clean(md(str(body), base_url=url)) if body else ''

    return {
        'year': year,
        'month': month,
        'url': url,
        'title': _clean(title.text) if title else '',
        'author': _clean(author.text) if author else '',
        'author_role': _clean(author_role.text) if author_role else '',
        'content': content,
        'html': html,
    }

# %%
def get_talk_path(url):
    path_components = urlparse(url).path.split('/')
    year, month, title = path_components[3:6]
    return os.path.join(base_dir, f"{year}-{month}-{title}.json")    


def write_talk_info(path, talk_info):
    with open(path, 'w', encoding='utf-8') as f:
        json.dump(talk_info, f, ensure_ascii=False, indent=2)

# %%
for year in years:
    for month in months:
        dir_url = f"{host}/study/general-conference/{year}/{month}?lang=eng"
        print(dir_url)
        status_code, dir_html = get_page(dir_url, headers, encoding)
        if status_code != 200:
            print(f"Status code={status_code} url={dir_url}")
            continue
        talk_urls = get_talk_urls(dir_url, dir_html)
        for talk_url in talk_urls:
            path = get_talk_path(talk_url)
            if os.path.exists(path):
                continue
            print("    ", path)
            status_code, talk_html = get_page(talk_url, headers, encoding)
            if status_code != 200:
                print(f"Status code={status_code} url={dir_url}")
                continue
            talk_info = get_talk_info(talk_url, talk_html)
            write_talk_info(path, talk_info)
            time.sleep(seconds_delay)
# Out:
# https://www.churchofjesuschrist.org/study/general-conference/1980/04?lang=eng
#      ../data/1980-04-no-unhallowed-hand-can-stop-the-work.json
#      ../data/1980-04-preparing-the-way.json
#      ../data/1980-04-he-is-not-here-he-is-risen.json
#      ../data/1980-04-communion-with-the-holy-spirit.json
#      ../data/1980-04-celestial-marriages-and-eternal-families.json
#      ../data/1980-04-church-finance-committee-report.json
#      ../data/1980-04-introduction-to-the-proclamation.json
#      ../data/1980-04-proclamation.json
#      ../data/1980-04-remarks-and-dedication-of-the-fayette-new-york-buildings.json
#      ../data/1980-04-what-hath-god-wrought-through-his-servant-joseph.json
#      ../data/1980-04-a-tribute-to-the-rank-and-file-of-the-church.json
#      ../data/1980-04-the-book-of-mormon.json
#      ../data/1980-04-where-do-we-stand.json
#      ../data/1980-04-the-coming-tests-and-trials-and-glory.json
#      ../data/1980-04-nauvoo-a-demonstration-of-faith.json
#      ../data/1980-04-self-accountability-and-human-progress.json
#      ../data/1980-04-the-gospel-restored.json
#      ../data/1980-04-let-us-not-weary-in-well-doing.json
#      ../data/1980-04-church-welfare-temporal-service-in-a-spiritual-setting.json
#      ../data/1980-04-an-example-of-what-welfare-services-can-do.json
#      ../data/1980-04-welfare-principles-in-relief-society.json
#      ../data/1980-04-welfare-services-past-present-and-future.json
#      ../data/1980-04-priesthood-councils-key-to-meeting-temporal-and-spiritual-needs.json
#      ../data/1980-04-a-deep-commitment-to-the-principles-of-welfare-service.json
# https://www.churchofjesuschrist.org/study/general-conference/1980/10?lang=eng
#      ../data/1980-10-families-can-be-eternal.json
#      ../data/1980-10-the-blessing-of-a-testimony.json
#      ../data/1980-10-for-whatsoever-a-man-soweth-that-shall-he-also-reap.json
#      ../data/1980-10-the-house-of-the-lord.json
#      ../data/1980-10-know-the-shepherd.json
#      ../data/1980-10-the-net-gathers-of-every-kind.json
#      ../data/1980-10-adam-the-archangel.json
#      ../data/1980-10-the-sustaining-of-church-officers.json
#      ../data/1980-10-the-choice.json
#      ../data/1980-10-the-saviors-touch.json
#      ../data/1980-10-our-thirtieth-anniversary-as-latter-day-saints.json
#      ../data/1980-10-feed-my-sheep.json
#      ../data/1980-10-forgive-them-i-pray-thee.json
#      ../data/1980-10-prepare-for-the-days-of-tribulation.json
#      ../data/1980-10-these-i-will-make-my-leaders.json
#      ../data/1980-10-purify-our-minds-and-spirits.json
#      ../data/1980-10-to-the-young-men-of-the-church.json
#      ../data/1980-10-the-oath-and-covenant-which-belongeth-to-the-priesthood.json
#      ../data/1980-10-ministering-to-the-needs-of-members.json
#      ../data/1980-10-repentance.json
#      ../data/1980-10-the-lord-god-of-the-restoration.json
#      ../data/1980-10-seven-events-of-great-consequence.json
#      ../data/1980-10-adversity-and-you.json
#      ../data/1980-10-of-you-it-is-required-to-forgive.json
#      ../data/1980-10-a-testimony.json
#      ../data/1980-10-acquaint-thyself-with-him-and-be-at-peace.json
#      ../data/1980-10-miracles-among-the-lamanites.json
#      ../data/1980-10-let-every-man-learn-his-duty.json
#      ../data/1980-10-decide-to-decide.json
#      ../data/1980-10-the-keys-of-the-kingdom.json
#      ../data/1980-10-do-not-weary-by-the-way.json
#      ../data/1980-10-the-law-of-tithing.json
#      ../data/1980-10-prepare-every-needful-thing.json
#      ../data/1980-10-the-household-of-faith.json
#      ../data/1980-10-follow-joyously.json
#      ../data/1980-10-is-any-thing-too-hard-for-the-lord.json
#      ../data/1980-10-the-bishop-center-stage-in-welfare.json
#      ../data/1980-10-welfare-services-the-saviors-program.json
#      ../data/1980-10-learn-then-teach.json
#      ../data/1980-10-the-bond-of-charity.json
#      ../data/1980-10-motherhood-and-the-family.json
#      ../data/1980-10-singleness-how-relief-society-can-help.json
#      ../data/1980-10-the-doctrines-of-the-kingdom.json
#      ../data/1980-10-organize-yourselves.json
#      ../data/1980-10-the-circle-of-sisters.json
# https://www.churchofjesuschrist.org/study/general-conference/1981/04?lang=eng
#      ../data/1981-04-the-sustaining-of-church-officers.json
#      ../data/1981-04-a-report-of-my-stewardship.json
#      ../data/1981-04-the-dignity-of-self.json
#      ../data/1981-04-we-are-called-to-spread-the-light.json
#      ../data/1981-04-marriage.json
#      ../data/1981-04-the-restoration-of-israel-to-the-lands-of-their-inheritance.json
#      ../data/1981-04-church-audit-committee-report.json
#      ../data/1981-04-statistical-report-1980.json
#      ../data/1981-04-the-joseph-smith-iii-document-and-the-keys-of-the-kingdom.json
#      ../data/1981-04-we-serve-that-which-we-love.json
#      ../data/1981-04-building-bridges-to-faith.json
#      ../data/1981-04-gracias.json
#      ../data/1981-04-light-and-truth.json
#      ../data/1981-04-call-of-the-prophets.json
#      ../data/1981-04-great-things-required-of-their-fathers.json
#      ../data/1981-04-fast-offerings-fulfilling-our-responsibility-to-others.json
#      ../data/1981-04-the-responsibility-of-young-aaronic-priesthood-bearers.json
#      ../data/1981-04-gospel-covenants.json
#      ../data/1981-04-rendering-service-to-others.json
#      ../data/1981-04-the-long-line-of-the-lonely.json
#      ../data/1981-04-he-is-there.json
#      ../data/1981-04-life-a-great-proving-ground.json
#      ../data/1981-04-love-one-another.json
#      ../data/1981-04-reach-out-to-our-fathers-children.json
#      ../data/1981-04-blessings-in-self-reliance.json
#      ../data/1981-04-no-man-shall-add-to-or-take-away.json
#      ../data/1981-04-moral-values-and-rewards.json
#      ../data/1981-04-obedience-full-obedience.json
#      ../data/1981-04-in-saving-others-we-save-ourselves.json
#      ../data/1981-04-turning-the-hearts.json
#      ../data/1981-04-upon-this-rock.json
#      ../data/1981-04-we-are-on-the-lords-errand.json
#      ../data/1981-04-follow-the-fundamentals.json
#      ../data/1981-04-our-responsibility-to-care-for-our-own.json
#      ../data/1981-04-reach-for-the-stars.json
#      ../data/1981-04-providing-for-our-needs.json
#      ../data/1981-04-the-need-to-teach-personal-and-family-preparedness.json
#      ../data/1981-04-the-basic-principles-of-church-welfare.json
# https://www.churchofjesuschrist.org/study/general-conference/1981/10?lang=eng
#      ../data/1981-10-the-sustaining-of-church-officers.json
#      ../data/1981-10-faith-the-essence-of-true-religion.json
#      ../data/1981-10-o-divine-redeemer.json
#      ../data/1981-10-the-plan-for-happiness-and-exaltation.json
#      ../data/1981-10-conference-time.json
#      ../data/1981-10-except-a-man-be-born-again.json
#      ../data/1981-10-he-is-risen.json
#      ../data/1981-10-examples-from-the-life-of-a-prophet.json
#      ../data/1981-10-the-light-of-the-gospel.json
#      ../data/1981-10-the-little-things-and-eternal-life.json
#      ../data/1981-10-the-strength-of-the-kingdom-is-within.json
#      ../data/1981-10-be-ye-prepared.json
#      ../data/1981-10-the-aaronic-priesthood.json
#      ../data/1981-10-the-ministry-of-the-aaronic-priesthood-holder.json
#      ../data/1981-10-when-ye-are-prepared-ye-shall-not-fear.json
#      ../data/1981-10-four-bs-for-boys.json
#      ../data/1981-10-the-perfect-law-of-liberty.json
#      ../data/1981-10-who-hath-believed-our-report.json
#      ../data/1981-10-sanctification-through-missionary-service.json
#      ../data/1981-10-to-follow-or-not-that-is-the-question.json
#      ../data/1981-10-people-to-people.json
#      ../data/1981-10-joseph-smith-prophet-to-our-generation.json
#      ../data/1981-10-follow-the-prophets.json
#      ../data/1981-10-opposition-to-the-work-of-god.json
#      ../data/1981-10-my-sheep-hear-my-voice.json
#      ../data/1981-10-teach-the-why.json
#      ../data/1981-10-my-specialty-is-mercy.json
#      ../data/1981-10-the-expanding-inheritance-from-joseph-smith.json
#      ../data/1981-10-remember-who-you-are.json
#      ../data/1981-10-love-extends-beyond-convenience.json
#      ../data/1981-10-a-safe-place-for-marriages-and-families.json
#      ../data/1981-10-finding-joy-by-serving-others.json
#      ../data/1981-10-being-strengthened-through-service.json
#      ../data/1981-10-give-with-wisdom-that-they-may-receive-with-dignity.json
#      ../data/1981-10-living-welfare-principles.json
#      ../data/1981-10-charity-never-faileth.json
#      ../data/1981-10-relief-society-in-times-of-transition.json
#      ../data/1981-10-an-opportunity-for-continual-learning.json
#      ../data/1981-10-relief-society-in-welfare.json
#      ../data/1981-10-the-honored-place-of-woman.json
# https://www.churchofjesuschrist.org/study/general-conference/1982/04?lang=eng
#      ../data/1982-04-remember-the-mission-of-the-church.json
#      ../data/1982-04-the-resurrection-of-jesus.json
#      ../data/1982-04-this-is-no-harm.json
#      ../data/1982-04-beginning-again.json
#      ../data/1982-04-we-believe-in-being-honest.json
#      ../data/1982-04-church-audit-committee-report.json
#      ../data/1982-04-statistical-report-1981.json
#      ../data/1982-04-true-greatness.json
#      ../data/1982-04-a-lasting-marriage.json
#      ../data/1982-04-pondering-strengthens-the-spiritual-life.json
#      ../data/1982-04-spiritual-guides-for-teachers-of-righteousness.json
#      ../data/1982-04-gods-love-for-us-transcends-our-transgressions.json
#      ../data/1982-04-what-the-gospel-teaches.json
#      ../data/1982-04-the-doctrine-of-the-priesthood.json
#      ../data/1982-04-priesthood-activation.json
#      ../data/1982-04-a-brother-offended.json
#      ../data/1982-04-tithing-an-opportunity-to-prove-our-faithfulness.json
#      ../data/1982-04-priesthood.json
#      ../data/1982-04-five-million-members-a-milestone-and-not-a-summit.json
#      ../data/1982-04-integrity-the-mother-of-many-virtues.json
#      ../data/1982-04-the-power-of-family-prayer.json
#      ../data/1982-04-let-us-go-up-to-the-house-of-god.json
#      ../data/1982-04-sailing-safely-the-seas-of-life.json
#      ../data/1982-04-sustaining-of-church-officers.json
#      ../data/1982-04-valiant-in-the-testimony-of-jesus.json
#      ../data/1982-04-the-first-and-the-last-words.json
#      ../data/1982-04-the-future-history-of-the-church.json
#      ../data/1982-04-love-is-the-power-that-will-cure-the-family.json
#      ../data/1982-04-what-temples-are-for.json
#      ../data/1982-04-jesus-is-our-savior.json
#      ../data/1982-04-let-us-improve-ourselves.json
#      ../data/1982-04-the-lord-is-at-the-helm.json
#      ../data/1982-04-the-value-of-work.json
#      ../data/1982-04-her-children-arise-up-and-call-her-blessed.json
#      ../data/1982-04-employment-challenges-in-the-1980s.json
#      ../data/1982-04-the-gospel-the-foundation-for-our-career.json
#      ../data/1982-04-work-and-welfare-a-historical-perspective.json
#      ../data/1982-04-an-invitation-to-grow.json
#      ../data/1982-04-reach-for-joy.json
#      ../data/1982-04-hearts-so-similar.json
#      ../data/1982-04-even-as-i-am.json
# https://www.churchofjesuschrist.org/study/general-conference/1982/10?lang=eng
#      ../data/1982-10-the-lord-expects-righteousness.json
#      ../data/1982-10-what-this-work-is-all-about.json
#      ../data/1982-10-love-all.json
#      ../data/1982-10-my-soul-delighteth-in-the-scriptures.json
#      ../data/1982-10-believers-and-doers.json
#      ../data/1982-10-the-sustaining-of-church-officers.json
#      ../data/1982-10-run-boy-run.json
#      ../data/1982-10-lds-hymns-worshiping-with-song.json
#      ../data/1982-10-faith-the-force-of-life.json
#      ../data/1982-10-look-to-god.json
#      ../data/1982-10-for-a-bishop-must-be-blameless.json
#      ../data/1982-10-the-seven-christs.json
#      ../data/1982-10-activating-young-men-of-the-aaronic-priesthood.json
#      ../data/1982-10-how-we-promote-activation.json
#      ../data/1982-10-revitalizing-aaronic-priesthood-quorums.json
#      ../data/1982-10-prepare-the-heart-of-your-son.json
#      ../data/1982-10-the-priesthood-of-aaron.json
#      ../data/1982-10-the-power-of-the-priesthood.json
#      ../data/1982-10-gratitude-and-thanksgiving.json
#      ../data/1982-10-scriptures.json
#      ../data/1982-10-the-meaning-of-maturity.json
#      ../data/1982-10-commitment-to-god.json
#      ../data/1982-10-fundamentals-of-enduring-family-relationships.json
#      ../data/1982-10-the-pearl-of-great-price.json
#      ../data/1982-10-pure-religion.json
#      ../data/1982-10-be-of-good-cheer.json
#      ../data/1982-10-be-a-friend-a-servant-a-son-of-the-savior.json
#      ../data/1982-10-however-faint-the-light-may-glow.json
#      ../data/1982-10-behold-my-beloved-son-in-whom-i-am-well-pleased.json
#      ../data/1982-10-reach-out-in-love-and-kindness.json
#      ../data/1982-10-let-us-do-as-we-have-been-counseled.json
#      ../data/1982-10-preparation-for-tomorrow.json
#      ../data/1982-10-application-of-welfare-principles-in-the-home-a-key-to-many-family-problems.json
#      ../data/1982-10-the-blessings-of-family-work-projects.json
#      ../data/1982-10-the-blessings-we-receive-as-we-meet-the-challenges-of-economic-stress.json
#      ../data/1982-10-the-celestial-nature-of-self-reliance.json
# https://www.churchofjesuschrist.org/study/general-conference/1983/04?lang=eng
#      ../data/1983-04-the-sustaining-of-church-officers.json
#      ../data/1983-04-he-slumbers-not-nor-sleeps.json
#      ../data/1983-04-shine-as-lights-in-the-world.json
#      ../data/1983-04-the-sacrament.json
#      ../data/1983-04-evidences-of-the-resurrection.json
#      ../data/1983-04-unity.json
#      ../data/1983-04-church-audit-committee-report.json
#      ../data/1983-04-statistical-report-1982.json
#      ../data/1983-04-the-keys-of-the-kingdom.json
#      ../data/1983-04-valiance-in-the-drama-of-life.json
#      ../data/1983-04-that-ye-may-have-roots-and-branches.json
#      ../data/1983-04-the-gospel-of-jesus-christ-and-basic-needs-of-people.json
#      ../data/1983-04-receiving-a-prophet.json
#      ../data/1983-04-straightway.json
#      ../data/1983-04-a-royal-generation.json
#      ../data/1983-04-within-the-clasp-of-your-arms.json
#      ../data/1983-04-muddy-feet-and-white-shirts.json
#      ../data/1983-04-enriching-family-life.json
#      ../data/1983-04-a-call-to-the-priesthood-feed-my-sheep.json
#      ../data/1983-04-overpowering-the-goliaths-in-our-lives.json
#      ../data/1983-04-a-principle-with-a-promise.json
#      ../data/1983-04-anonymous.json
#      ../data/1983-04-repentance.json
#      ../data/1983-04-finding-ones-identity.json
#      ../data/1983-04-creator-and-savior.json
#      ../data/1983-04-agency-and-control.json
#      ../data/1983-04-teaching-no-greater-call.json
#      ../data/1983-04-to-forgive-is-divine.json
#      ../data/1983-04-profanity-and-swearing.json
#      ../data/1983-04-climbing-to-higher-spirituality.json
#      ../data/1983-04-train-up-a-child.json
#      ../data/1983-04-fear-not-to-do-good.json
# https://www.churchofjesuschrist.org/study/general-conference/1983/10?lang=eng
#      ../data/1983-10-the-sustaining-of-church-officers.json
#      ../data/1983-10-except-ye-are-one.json
#      ../data/1983-10-jesus-christ-our-savior-and-redeemer.json
#      ../data/1983-10-the-keystone-of-our-religion.json
#      ../data/1983-10-our-father-which-art-in-heaven.json
#      ../data/1983-10-parent-child-interviews.json
#      ../data/1983-10-the-mystery-of-life.json
#      ../data/1983-10-labels.json
#      ../data/1983-10-agency-and-love.json
#      ../data/1983-10-friend-or-foe.json
#      ../data/1983-10-honour-thy-father-and-thy-mother.json
#      ../data/1983-10-the-house-of-the-lord.json
#      ../data/1983-10-the-angel-moroni-came.json
#      ../data/1983-10-our-responsibility-to-take-the-gospel-to-the-ends-of-the-earth.json
#      ../data/1983-10-the-blessings-of-missionary-service.json
#      ../data/1983-10-called-as-if-he-heard-a-voice-from-heaven.json
#      ../data/1983-10-become-a-star-thrower.json
#      ../data/1983-10-what-manner-of-men-ought-we-to-be.json
#      ../data/1983-10-be-not-deceived.json
#      ../data/1983-10-god-grant-us-faith.json
#      ../data/1983-10-joseph-the-seer.json
#      ../data/1983-10-be-a-peacemaker.json
#      ../data/1983-10-removing-the-poison-of-an-unforgiving-spirit.json
#      ../data/1983-10-the-word-is-commitment.json
#      ../data/1983-10-parents-concern-for-children.json
#      ../data/1983-10-your-sorrow-shall-be-turned-to-joy.json
#      ../data/1983-10-how-do-you-know.json
#      ../data/1983-10-the-power-to-make-a-difference.json
#      ../data/1983-10-what-think-ye-of-the-book-of-mormon.json
#      ../data/1983-10-let-us-go-forward.json
#      ../data/1983-10-live-up-to-your-inheritance.json
#      ../data/1983-10-a-season-for-strength.json
#      ../data/1983-10-prepare-to-teach-his-children.json
#      ../data/1983-10-agency-and-accountability.json
# https://www.churchofjesuschrist.org/study/general-conference/1984/04?lang=eng
#      ../data/1984-04-the-sustaining-of-church-officers.json
#      ../data/1984-04-counsel-to-the-saints.json
#      ../data/1984-04-choose-the-good-part.json
#      ../data/1984-04-marriage-and-divorce.json
#      ../data/1984-04-jesus-the-christ-the-words-and-their-meaning.json
#      ../data/1984-04-building-your-eternal-home.json
#      ../data/1984-04-the-church-audit-committee-report.json
#      ../data/1984-04-statistical-report-1983.json
#      ../data/1984-04-the-great-plan-of-the-eternal-god.json
#      ../data/1984-04-covenants-ordinances-and-service.json
#      ../data/1984-04-a-generation-prepared-to-make-wise-choices.json
#      ../data/1984-04-coming-through-the-mists.json
#      ../data/1984-04-warmed-by-the-fires-of-their-lives.json
#      ../data/1984-04-home-and-family-a-divine-eternal-pattern.json
#      ../data/1984-04-patterns-of-prayer.json
#      ../data/1984-04-missions-only-you-can-decide.json
